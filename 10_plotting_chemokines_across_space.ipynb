# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scanpy as sc
import os

# %%
input_file = "/mnt/sata4/Alex_Xenium_Data/20250717__210317__2025_07_17_perturb8_LCMV_run1/Liver"
path_to_reference_adata = os.path.join(input_file, 'combined', 'final_object.h5ad')
adata = sc.read(path_to_reference_adata)

# %%
SI_file = "/mnt/sata4/Alex_Xenium_Data/20250717__210317__2025_07_17_perturb8_LCMV_run1/SI/combined/guides_assigned.h5ad"
adata_SI = sc.read(SI_file)

# %%
adata_SI.obs.columns
# Out:
# Index(['x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts',
#        'genomic_control_counts', 'control_codeword_counts',
#        'unassigned_codeword_counts', 'deprecated_codeword_counts',
#        'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count',
#        'segmentation_method', 'total_transcripts', 'nuclear_transcripts',
#        'cytoplasmic_transcripts', 'nuclear_transcript_percentage', 'topic',
#        'transduced', 'batch', '_scvi_batch', '_scvi_labels', 'Subtype',
#        'n_counts', '_indices', 'resolvi_predicted', 'cluster_cellcharter',
#        'peyers', 'reference_crypt_villi', 'villi_number', 'Topic 1', 'Topic 2',
#        'Topic 3', 'Topic 4', 'Topic 5', 'Topic 6', 'crypt_villi_axis',
#        'epithelial_distance', 'epithelial_distance_clipped', 'guide_rnas'],
#       dtype='object')

# %%
adata.obs
# Out:
#              x_centroid    y_centroid  transcript_counts  \
# aaaammla-1  1671.903564  11030.593750                238
# aaabjgim-1  1294.131104   3818.937988                480
# aaachnjc-1  1280.756104   3810.283203                847
# aaacjofc-1  1292.485718   3781.820801                356
# aaacpdgf-1  1273.486328   3777.537598                399
# ...                 ...           ...                ...
# oilcopll-1  2918.909668   4731.865234                133
# oilfbcpl-1  2856.203369   4560.718750                283
# oilfebdb-1  2591.339111   4296.415039                142
# oilfkpfh-1  2659.871826   4706.128418                110
# oilgohhn-1  2629.626221   4146.229492                233
#
#             control_probe_counts  genomic_control_counts  \
# aaaammla-1                     0                       0
# aaabjgim-1                     0                       0
# aaachnjc-1                     0                       0
# ...

# %%
interacting_partners = {
    "Ccl1": ["Ccr8"],
    "Ccl2": ["Ccr2", "Ccr4"],
    "Ccl3": ["Ccr1", "Ccr5", "Ccr4"],
    "Ccl4": ["Ccr5", "Ccr1", "Ccr8"],
    "Ccl5": ["Ccr1", "Ccr4", "Ccr5"],
    "Ccl7": ["Ccr1", "Ccr2"],
    "Ccl8": ["Ccr2", "Ccr5", "Ccr8"],
    "Ccl12": ["Ccr2"],
    "Ccl17": ["Ccr4", "Ccr8"],
    "Ccl19": ["Ccr7"],
    "Ccl20": ["Ccr6"],
    "Ccl22": ["Ccr4"],
    "Ccl25": ["Ccr9"],
    "Cx3cl1": ["Cx3cr1"],
    "Cxcl9": ["Cxcr3"],
    "Cxcl10": ["Cxcr3"],
    "Cxcl12": ["Cxcr4"],
    "Cxcl13": ["Cxcr5"],
    "Cxcl16": ["Cxcr6"],
    "Xcl1": ["Xcr1"],
    "Ccr1": ["Ccl3", "Ccl4", "Ccl5", "Ccl7"],
    "Ccr2": ["Ccl2", "Ccl7", "Ccl8", "Ccl12"],
    "Ccr4": ["Ccl2", "Ccl3", "Ccl5", "Ccl17", "Ccl22"],
    "Ccr5": ["Ccl3", "Ccl4", "Ccl5", "Ccl8"],
    "Ccr6": ["Ccl20"],
    "Ccr7": ["Ccl19"],
    "Ccr8": ["Ccl1", "Ccl4", "Ccl8", "Ccl17"],
    "Ccr9": ["Ccl25"],
    "Cx3cr1": ["Cx3cl1"],
    "Cxcr3": ["Cxcl9", "Cxcl10"],
    "Cxcr4": ["Cxcl12"],
    "Cxcr5": ["Cxcl13"],
    "Cxcr6": ["Cxcl16"],
    "Xcr1": ["Xcl1"],
    "Il2": ["Il2ra", "Il2rb", "Il2rg"],
    "Il4": ["Il4ra", "Il2rg"],
    "Il6": ["Il6ra", "Il6st"],
    "Il7": ["Il7r", "Il2rg"],
    "Il10": ["Il10ra", "Il10rb"],
    "Il15": ["Il15ra", "Il2rb", "Il2rg"],
    "Il17a": ["Il17ra", "Il17rc"],
    "Il17f": ["Il17ra", "Il17rc"],
    "Il18": ["Il18r1", "Il18rap"],
    "Ifng": ["Ifngr1", "Ifngr2"],
    "Tgfb1": ["Tgfbr1", "Tgfbr2"],
    "Tgfb2": ["Tgfbr1", "Tgfbr2"],
    "Tgfb3": ["Tgfbr1", "Tgfbr2"],
    "Flt3l": ["Flt3"],
    "Il2ra": ["Il2"],
    "Il2rb": ["Il2", "Il15"],
    "Il2rg": ["Il2", "Il4", "Il7", "Il15"],
    "Il4ra": ["Il4"],
    "Il6ra": ["Il6"],
    "Il6st": ["Il6"],
    "Il7r": ["Il7"],
    "Il10ra": ["Il10"],
    "Il10rb": ["Il10"],
    "Il15ra": ["Il15"],
    "Il17ra": ["Il17a", "Il17f"],
    "Il17rc": ["Il17a", "Il17f"],
    "Il18r1": ["Il18"],
    "Il18rap": ["Il18"],
    "Ifngr1": ["Ifng"],
    "Ifngr2": ["Ifng"],
    "Tgfbr1": ["Tgfb1", "Tgfb2", "Tgfb3"],
    "Tgfbr2": ["Tgfb1", "Tgfb2", "Tgfb3"],
    "Flt3": ["Flt3l"]
}

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

os.makedirs('figures/10_plotting_chemokines_across_space', exist_ok=True)
batches = adata.obs['batch'].unique()

for gene in interacting_partners:
    for partner in interacting_partners[gene]:
        outpath = f'figures/10_plotting_chemokines_across_space/{gene}_{partner}.png'
        if os.path.exists(outpath):
            print(f'{gene}_{partner} already exists')
            continue

        fig, axs = plt.subplots(2, len(batches), figsize=(4 * len(batches), 8), squeeze=False)
        for row, name in enumerate([gene, partner]):
            for col, batch in enumerate(batches):
                sub = adata[adata.obs['batch'] == batch]
                x = sub.obsm['X_spatial'][:, 0]
                y = sub.obsm['X_spatial'][:, 1]
                w = sub[:, name].X.A.flatten()

                # 1) compute & plot the 2D histogram
                counts, xedges, yedges, im = axs[row, col].hist2d(
                    x, y,
                    bins=100,
                    weights=w,
                    cmap='viridis'
                )

                # 2) compute the 99th percentile of the nonzero bin‐counts
                nonzero = counts[counts > 0]
                if nonzero.size:
                    p99 = np.percentile(nonzero, 99)
                    # 3) clamp the color‐scale to [0, p99]
                    im.set_clim(0, p99)

                # titles & axes
                axs[row, col].set_title(f'{name} in {batch}')
                axs[row, col].set_xlabel('Spatial X')
                axs[row, col].set_ylabel('Spatial Y')

                # add a colorbar
                fig.colorbar(im, ax=axs[row, col], label='Weighted count')

        plt.tight_layout()
        fig.savefig(outpath, dpi=400)
        plt.close(fig)
